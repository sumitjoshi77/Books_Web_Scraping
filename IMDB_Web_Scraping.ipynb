# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitjoshi77/Books_Web_Scraping/blob/main/IMDB_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests, openpyxl

# %%
excel = openpyxl.Workbook()
sheet= excel.active
sheet.title= 'Top TV Shows List'
print(excel.sheetnames)
sheet.append(["Movie Rank","Movie Name","Yesr of Release","IMDB Rating"])
# Out:
# ['Top TV Shows List']

# %%
source = requests.get("https://www.imdb.com/chart/toptv/")
source.raise_for_status()

# %%
soup = BeautifulSoup(source.text, 'html.parser')

# %%
TVshows = soup.find('tbody', class_ = "lister-list").find_all("tr")

# %%
for TVshow in TVshows:
  name = TVshow.find('td', class_ = "titleColumn").a.text
  rank = TVshow.find('td', class_ = "titleColumn").get_text(strip=True).split('.')[0]
  year = TVshow.find('td', class_ = "titleColumn").span.text.strip('()')
  rating = TVshow.find('td', class_ = "ratingColumn imdbRating").strong.text
  print(rank,name,rating,year)
  sheet.append([rank,name,rating,year])
  excel.save("IMDB TV Show Rating.xlsx")
# Out:
# 1 Planet Earth II 9.4 2016
# 2 Breaking Bad 9.4 2008
# 3 Planet Earth 9.4 2006
# 4 Band of Brothers 9.4 2001
# 5 Chernobyl 9.3 2019
# 6 The Wire 9.3 2002
# 7 Blue Planet II 9.2 2017
# 8 Avatar: The Last Airbender 9.2 2005
# 9 Cosmos: A Spacetime Odyssey 9.2 2014
# 10 The Sopranos 9.2 1999
# 11 Cosmos 9.2 1980
# 12 Our Planet 9.2 2019
# 13 Game of Thrones 9.1 2011
# 14 The World at War 9.1 1973
# 15 Rick and Morty 9.1 2013
# 16 The Last of Us 9.1 2023
# 17 Fullmetal Alchemist: Brotherhood 9.0 2009
# 18 The Last Dance 9.0 2020
# 19 Life 9.0 2009
# 20 Sherlock 9.0 2010
# 21 The Twilight Zone 9.0 1959
# 22 The Vietnam War 9.0 2017
# 23 Bluey 9.0 2018
# 24 Batman: The Animated Series 9.0 1992
# 25 Scam 1992: The Harshad Mehta Story 8.9 2020
# 26 Arcane 8.9 2021
# 27 The Blue Planet 8.9 2001
# 28 Attack on Titan 8.9 2013
# 29 The Office 8.9 2005
# 30 Firefly 8.9 2002
# 31 Human Planet 8.9 2011
# 32 Frozen Planet 8.9 2011
# 33 Death Note 8.9 2006
# 34 Only Fools and Horses 8.9 1981
# ...
